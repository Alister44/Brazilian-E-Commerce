# %% [markdown]
# <a href="https://colab.research.google.com/github/Alister44/Brazilian-E-Commerce/blob/main/notebook/simple_predict_olist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python: simple forecast and recommendations
